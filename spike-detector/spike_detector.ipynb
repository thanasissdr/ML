# %%
# %load_ext nb_black

# %%
from typing import Any, Optional, List, Union

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from data import create_data
from detector import SpikeDetectorFixed, SpikeDetectorMovingAverage
from main import SpikeDetectorRunner

# %%
sns.set_theme("notebook")

# %% [markdown]
# # Create data

# %%
KWARGS = {"low": 240, "high": 240, "loc": 240, "scale": 20}

data = create_data(**KWARGS)

# %%
df = pd.Series(data)

# %% [markdown]
# ## Spike Detector Fixed

# %%
spike_detector_fixed = SpikeDetectorFixed(upper_bound=240.1)
spike_detector_runner = SpikeDetectorRunner(spike_detector=spike_detector_fixed)

fig, ax = plt.subplots(1, 1, figsize=(16, 8))

spike_detector_runner.run(data, color="black", marker="x", alpha=1, ax=ax)

# %% [markdown]
# ## Spike Detector Moving Average

# %%
data[:3]
# Out:
# array([240., 240., 240.])

# %%
spike_detector_moving_average = SpikeDetectorMovingAverage(
    window=3, threshold=3.0, detect_sag=True
)
spike_detector_runner = SpikeDetectorRunner(
    spike_detector=spike_detector_moving_average
)

fig, ax = plt.subplots(1, 1, figsize=(16, 8))

spike_detector_runner.run(data[:7], color="black", marker="x", alpha=1, ax=ax)

# %% [markdown]
# # <font color="green"> TEST </font>
